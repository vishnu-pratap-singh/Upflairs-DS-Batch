# %%
import matplotlib.pyplot as plt

# %%
x=[1, 2, 3, 4, 5]
y=[2, 3, 5, 7, 11]

plt.plot(
    x,
    y,
    label='sales va revenue',
    color='red',
    linewidth=2,
   
   


)

plt.xlabel='sale',
plt.ylabel='revenue',

plt.show()

# %%
#Scattered plot

# %%
students=['A', 'B', 'C', 'D', 'E']
marks=[23, 45, 56, 78, 90]
plt.barh(students, marks, color='green')
plt.title('students marks')
plt.show()

# %%
ages=[18,19,20,21,22,25,28,32,]
plt.hist(ages, bins=5, color='blue')
plt.title('age distribution')
plt.show()

# %%
#pie chart 
subject=['maths', 'science', 'english', 'history']
students=[30, 25, 20, 15]
plt.pie(students, labels=subject, autopct='%1.1f%%')
plt.title('students distribution')
plt.show()

# %%
# box plot
ages=[18,19,20,21,22,25,28,32,]
plt.title('Box plot of age distribution')
plt.boxplot(ages)
plt.show()

# %%
#area plot
x=[1, 2, 3, 4, 5]
y=[2, 3, 5, 7, 11]
plt.fill_between(x, y, color='orange', alpha=0.5)
plt.title('Area plot')
plt.show()

# %%
# squatre  and linear plot
x=[1, 2, 3, 4, 5]
y=[1, 4, 9, 16, 25]
plt.plot(x, y, label='Squares')
plt.plot(x, [i**2 for i in x], label='Linear')
plt.legend()
plt.title('Square and Linear plot')
plt.show()

# %%
x1=[1, 2, 3, 4, 5]
x2=[5,6,7,8,9]
y1=[2,3,5,7,11]
y2=[1,2,3,4]
plt.subplot(1,2,1)
plt.plot(x1,y1)
plt.title('Graph 1')

plt.subplot(1,2,2)
plt.plot(x2,y2)
plt.title('Graph 2')

plt.subplot(2,2,3)
plt.plot(X2,y1)
plt.title('Graph 3')

plt.subplot(2,2,4)
plt.plot(x1,y2)
plt.title('Graph 4')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 10
#       6 plt.plot(x1,y1)
#       7 plt.title('Graph 1')
#       8
#       9 plt.subplot(1,2,2)
# ---> 10 plt.plot(x2,y2)
#      11 plt.title('Graph 2')
#      12
#      13 plt.subplot(2,2,3)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
#    3830 @_copy_docstring_and_deprecators(Axes.plot)
#    3831 def plot(
#    3832     *args: float | ArrayLike | str,
#    (...)   3836     **kwargs,
#    3837 ) -> list[Line2D]:
# -> 3838     return gca().plot(
#    3839         *args,
#    3840         scalex=scalex,
#    3841         scaley=scaley,
#    3842         **({"data": data} if data is not None else {}),
#    3843         **kwargs,
#    3844     )
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[14], line 3
#       1 import matplotlib.image as mping
#       2
# ----> 3 img =mping.imread(r'C:\Users\HP\OneDrive\Desktop\intership\python')
#       4 plt.imshow(img)
#       5 plt.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\matplotlib\image.py:1520, in imread(fname, format)
#    1513 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1514     # Pillow doesn't handle URLs directly.
#    1515     raise ValueError(
#    1516         "Please open the URL for reading and pass the "
#    1517         "result to Pillow, e.g. with "
#    1518         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1519         )
# -> 1520 with img_open(fname) as image:
# ...

# %%
import matplotlib.image as mpimg  # Fixed the typo here ('mpimg')
import matplotlib.pyplot as plt

# 1. Update the path with your exact file name and extension
img_path = r'C:\Users\HP\OneDrive\Desktop\intership\python\8085-architecture.jpg'

# 2. Read and display the image
img = mpimg.imread(img_path)
plt.imshow(img)
plt.show()

# %%
import pandas as pd
import seaborn as sns
data={
    "student":['A', 'B', 'C'],
    "marks":[38,78,99] 



}
df=pd.DataFrame(data)
sns.barplot(x='student', y='marks', data=df)
plt.title('Stuents marks')
plt.show()

# %%
data={
    "math": [85, 90, 78, 92, 88],
    "Science": [80, 85, 90, 95, 88],
    "English": [75, 80, 85, 90, 95]
}
df=pd.DataFrame(data)
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
#create a dataset of 5 students and teir marks in mathematics

# %% [markdown]
# # create a dataset of 5 students and teir marks in mathematics
#
# ## task
# ** create a bar chart  using matplotlib ## add title
# *** x-label
# *** y-label
# *** different colors grid ,
# *** display marks on the graph using markers or labels

# %%
import matplotlib.pyplot as plt
students= ['A', 'B', 'C', 'D','E']
marks= [23, 45, 56, 78, 90]
colors=['red', 'blue', 'green', 'orange', 'purple']


plt.bar(students, marks, color=colors)
plt.title('students marks')
plt.xlabel('students Name')
plt.ylabel('marks')
plt.grid(color='gray' , linestyle='--', linewidth=0.5)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 9
#       5
#       6
#       7 plt.bar(students, marks, color=colors)
#       8 plt.title('studnets marks')
# ----> 9 plt.xLabel('students Name')
#      10 plt.ylabel('marks')
#      11 plt.grid(color='gray' , linestyle='--', linewidth=0.5)
#      12
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xLabel'

# %% [markdown]
# Montehly temperature visualization  create a two lists
# months
# temperature
# tasks
# plot a line graph uing matpotlib
# markers
# legends
# figure size
# show temperature change over months

# %%
months=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
temperature=[30, 32, 28, 25, 27, 29, 31, 33, 26, 24, 22, 20]

plt.plot(months, temperature, marker='o', linestyle='-', color='blue')
plt.title('Monthly Temperatures')
plt.xlabel('Months')
plt.ylabel('temperature (°C)')
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 6
#       2 temperature=[30, 32, 28, 25, 27, 29, 31, 33, 26, 24, 22, 20]
#       3
#       4 plt.plot(months, temperature, marker='o', linestyle='-', color='blue')
#       5 plt.title('Monthly Temperatures')
# ----> 6 plt.xlabel('Months')
#       7 plt.ylabel('temperature (°C)')
#       8 plt.grid(color='gray', linestyle='--', linewidth=0.5)
#       9 plt.show()
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# students marks Analysis
# cretae a data set of 5 students and tahir marks in mathmatics
#
# tasks :
# Add
# Title
# x-labels
# y-labela
# different colors
# Grid
# Display marks on the graph uing markers or labels

# %%
students=['A', 'B', 'C', 'D', 'E']
marks=[23, 45, 56, 78, 90]
plt.barh(students, marks, color='green')
plt.title('students marks')
plt.xlabel('marks')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 5
#       1 students=['A', 'B', 'C', 'D', 'E']
#       2 marks=[23, 45, 56, 78, 90]
#       3 plt.barh(students, marks, color='green')
#       4 plt.title('students marks')
# ----> 5 plt.xlabel('marks')
#       6 plt.show()
#
# TypeError: 'tuple' object is not callable
